# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import tqdm
from numba import njit, prange

import generator
import fast_generator
from cmaps import *

# %% [markdown]
# # Generating a forest

# %%
forest = fast_generator.generate_forest(8,2,temp=1.5, maxiter=1000000)
# Out:
# completed in 2856 iterations
# merge pattern found after 526 iterations, temp = 1500e-3

# %%
fast_generator.plot_forest(forest, solution=True, cmap=desert_cmap())

# %% [markdown]
# # Depth first search of a simple forest

# %%
trees = fast_generator.plant_trees(6, 1, maxiter = 1000000)
plt.imshow(trees)

# %%
start = time.time()
singular_roots = fast_generator.generate_singular_roots(trees)
print(f"time = {time.time() - start}")
plt.imshow(singular_roots)

# %%
start = time.time()
solutions, visited = generator.place_tree(singular_roots)
print(f"time = {time.time() - start}")

if len(solutions) == 1:
    plt.imshow(solution)
else:
    fig, ax = plt.subplots(1, len(solutions), figsize=(len(solutions)*2, 2))
    for i,solution in enumerate(solutions):
        ax[i].imshow(solution)
        ax[i].set_xticks([])
        ax[i].set_yticks([])
    plt.show()

# %% [markdown]
# # Components of forest generation

# %%
trees = fast_generator.plant_trees(10, 2, maxiter = 1000000)

plt.imshow(trees)
# Out:
# completed in 31 iterations

# %%
singular_roots = fast_generator.generate_singular_roots(trees)
plt.imshow(singular_roots)

# %%
adj_mat = fast_generator.adj_mat_from_roots(singular_roots)
plt.imshow(adj_mat)

# %%
# %timeit roots = fast_generator.merge_roots(singular_roots, temp=1.5, maxiter=1000000)
# Out:
# merge pattern found after 5692 iterations, temp = 1576e-3
# merge pattern found after 913 iterations, temp = 1500e-3
# merge pattern found after 1647 iterations, temp = 1515e-3
# merge pattern found after 2992 iterations, temp = 1530e-3
# merge pattern found after 1780 iterations, temp = 1515e-3
# merge pattern found after 2147 iterations, temp = 1530e-3
# merge pattern found after 5740 iterations, temp = 1576e-3
# merge pattern found after 1708 iterations, temp = 1515e-3
# merge pattern found after 1650 iterations, temp = 1515e-3
# merge pattern found after 4133 iterations, temp = 1560e-3
# merge pattern found after 70 iterations, temp = 1500e-3
# merge pattern found after 232 iterations, temp = 1500e-3
# merge pattern found after 302 iterations, temp = 1500e-3
# merge pattern found after 1004 iterations, temp = 1515e-3
# merge pattern found after 1465 iterations, temp = 1515e-3
# merge pattern found after 649 iterations, temp = 1500e-3
# merge pattern found after 4074 iterations, temp = 1560e-3
# merge pattern found after 325 iterations, temp = 1500e-3
# merge pattern found after 1009 iterations, temp = 1515e-3
# merge pattern found after 1047 iterations, temp = 1515e-3
# merge pattern found after 5147 iterations, temp = 1576e-3
# merge pattern found after 988 iterations, temp = 1500e-3
# merge pattern found after 3871 iterations, temp = 1545e-3
# merge pattern found after 2445 iterations, temp = 1530e-3
# merge pattern found after 821 iterations, temp = 1500e-3
# merge pattern found after 105 iterations, temp = 1500e-3
# merge pattern found after 240 iterations, temp = 1500e-3
# merge pattern found after 243 iterations, temp = 1500e-3
# merge pattern found after 855 iterations, temp = 1500e-3
# merge pattern found after 206 iterations, temp = 1500e-3
# merge pattern found after 80 iterations, temp = 1500e-3
# merge pattern found after 3305 iterations, temp = 1545e-3
# merge pattern found after 1147 iterations, temp = 1515e-3
# merge pattern found after 3717 iterations, temp = 1545e-3
# merge pattern found after 3746 iterations, temp = 1545e-3
# merge pattern found after 222 iterations, temp = 1500e-3
# merge pattern found after 40 iterations, temp = 1500e-3
# merge pattern found after 1424 iterations, temp = 1515e-3
# merge pattern found after 153 iterations, temp = 1500e-3
# merge pattern found after 826 iterations, temp = 1500e-3
# merge pattern found after 1473 iterations, temp = 1515e-3
# merge pattern found after 1248 iterations, temp = 1515e-3
# merge pattern found after 3576 iterations, temp = 1545e-3
# merge pattern found after 5706 iterations, temp = 1576e-3
# merge pattern found after 1775 iterations, temp = 1515e-3
# merge pattern found after 1566 iterations, temp = 1515e-3
# merge pattern found after 1836 iterations, temp = 1515e-3
# merge pattern found after 1907 iterations, temp = 1515e-3
# merge pattern found after 3231 iterations, temp = 1545e-3
# merge pattern found after 635 iterations, temp = 1500e-3
# merge pattern found after 1475 iterations, temp = 1515e-3
# merge pattern found after 199 iterations, temp = 1500e-3
# merge pattern found after 1303 iterations, temp = 1515e-3
# merge pattern found after 2128 iterations, temp = 1530e-3
# merge pattern found after 1751 iterations, temp = 1515e-3
# merge pattern found after 2293 iterations, temp = 1530e-3
# merge pattern found after 8004 iterations, temp = 1624e-3
# merge pattern found after 1708 iterations, temp = 1515e-3
# merge pattern found after 561 iterations, temp = 1500e-3
# merge pattern found after 289 iterations, temp = 1500e-3
# merge pattern found after 4913 iterations, temp = 1560e-3
# merge pattern found after 172 iterations, temp = 1500e-3
# merge pattern found after 2616 iterations, temp = 1530e-3
# merge pattern found after 970 iterations, temp = 1500e-3
# merge pattern found after 1040 iterations, temp = 1515e-3
# merge pattern found after 2163 iterations, temp = 1530e-3
# merge pattern found after 3753 iterations, temp = 1545e-3
# merge pattern found after 839 iterations, temp = 1500e-3
# merge pattern found after 4904 iterations, temp = 1560e-3
# merge pattern found after 2607 iterations, temp = 1530e-3
# merge pattern found after 165 iterations, temp = 1500e-3
# merge pattern found after 8196 iterations, temp = 1624e-3
# merge pattern found after 1575 iterations, temp = 1515e-3
# merge pattern found after 852 iterations, temp = 1500e-3
# merge pattern found after 632 iterations, temp = 1500e-3
# merge pattern found after 1914 iterations, temp = 1515e-3
# merge pattern found after 811 iterations, temp = 1500e-3
# merge pattern found after 352 iterations, temp = 1500e-3
# merge pattern found after 1773 iterations, temp = 1515e-3
# merge pattern found after 846 iterations, temp = 1500e-3
# merge pattern found after 4294 iterations, temp = 1560e-3
# merge pattern found after 1829 iterations, temp = 1515e-3
# merge pattern found after 2042 iterations, temp = 1530e-3
# merge pattern found after 1364 iterations, temp = 1515e-3
# merge pattern found after 363 iterations, temp = 1500e-3
# merge pattern found after 1141 iterations, temp = 1515e-3
# merge pattern found after 88 iterations, temp = 1500e-3
# merge pattern found after 772 iterations, temp = 1500e-3
# merge pattern found after 7239 iterations, temp = 1608e-3
# merge pattern found after 2996 iterations, temp = 1530e-3
# merge pattern found after 2470 iterations, temp = 1530e-3
# merge pattern found after 1668 iterations, temp = 1515e-3
# merge pattern found after 3977 iterations, temp = 1545e-3
# merge pattern found after 1540 iterations, temp = 1515e-3
# merge pattern found after 1543 iterations, temp = 1515e-3
# merge pattern found after 343 iterations, temp = 1500e-3
# merge pattern found after 1752 iterations, temp = 1515e-3
# merge pattern found after 1371 iterations, temp = 1515e-3
# merge pattern found after 354 iterations, temp = 1500e-3
# merge pattern found after 1514 iterations, temp = 1515e-3
# merge pattern found after 369 iterations, temp = 1500e-3
# merge pattern found after 512 iterations, temp = 1500e-3
# merge pattern found after 321 iterations, temp = 1500e-3
# merge pattern found after 3155 iterations, temp = 1545e-3
# merge pattern found after 6262 iterations, temp = 1592e-3
# merge pattern found after 830 iterations, temp = 1500e-3
# merge pattern found after 243 iterations, temp = 1500e-3
# merge pattern found after 4020 iterations, temp = 1560e-3
# merge pattern found after 3005 iterations, temp = 1545e-3
# merge pattern found after 1824 iterations, temp = 1515e-3
# merge pattern found after 1883 iterations, temp = 1515e-3
# merge pattern found after 1558 iterations, temp = 1515e-3
# merge pattern found after 268 iterations, temp = 1500e-3
# merge pattern found after 564 iterations, temp = 1500e-3
# merge pattern found after 2014 iterations, temp = 1530e-3
# merge pattern found after 1446 iterations, temp = 1515e-3
# merge pattern found after 1810 iterations, temp = 1515e-3
# merge pattern found after 4067 iterations, temp = 1560e-3
# merge pattern found after 2479 iterations, temp = 1530e-3
# merge pattern found after 102 iterations, temp = 1500e-3
# merge pattern found after 5772 iterations, temp = 1576e-3
# merge pattern found after 233 iterations, temp = 1500e-3
# merge pattern found after 251 iterations, temp = 1500e-3
# merge pattern found after 342 iterations, temp = 1500e-3
# merge pattern found after 1414 iterations, temp = 1515e-3
# merge pattern found after 1778 iterations, temp = 1515e-3
# merge pattern found after 1242 iterations, temp = 1515e-3
# merge pattern found after 2639 iterations, temp = 1530e-3
# merge pattern found after 986 iterations, temp = 1500e-3
# merge pattern found after 620 iterations, temp = 1500e-3
# merge pattern found after 1182 iterations, temp = 1515e-3
# merge pattern found after 1872 iterations, temp = 1515e-3
# merge pattern found after 613 iterations, temp = 1500e-3
# merge pattern found after 470 iterations, temp = 1500e-3
# merge pattern found after 1663 iterations, temp = 1515e-3
# merge pattern found after 862 iterations, temp = 1500e-3
# merge pattern found after 415 iterations, temp = 1500e-3
# merge pattern found after 1360 iterations, temp = 1515e-3
# merge pattern found after 3632 iterations, temp = 1545e-3
# merge pattern found after 3747 iterations, temp = 1545e-3
# merge pattern found after 1699 iterations, temp = 1515e-3
# merge pattern found after 7194 iterations, temp = 1608e-3
# merge pattern found after 2456 iterations, temp = 1530e-3
# merge pattern found after 1117 iterations, temp = 1515e-3
# merge pattern found after 1430 iterations, temp = 1515e-3
# merge pattern found after 1461 iterations, temp = 1515e-3
# merge pattern found after 10096 iterations, temp = 1656e-3
# merge pattern found after 1414 iterations, temp = 1515e-3
# merge pattern found after 361 iterations, temp = 1500e-3
# merge pattern found after 2894 iterations, temp = 1530e-3
# merge pattern found after 1642 iterations, temp = 1515e-3
# merge pattern found after 1845 iterations, temp = 1515e-3
# merge pattern found after 1266 iterations, temp = 1515e-3
# merge pattern found after 1826 iterations, temp = 1515e-3
# merge pattern found after 1146 iterations, temp = 1515e-3
# merge pattern found after 1479 iterations, temp = 1515e-3
# merge pattern found after 1561 iterations, temp = 1515e-3
# merge pattern found after 3506 iterations, temp = 1545e-3
# merge pattern found after 3511 iterations, temp = 1545e-3
# merge pattern found after 9 iterations, temp = 1500e-3
# merge pattern found after 536 iterations, temp = 1500e-3
# merge pattern found after 380 iterations, temp = 1500e-3
# merge pattern found after 1223 iterations, temp = 1515e-3
# merge pattern found after 911 iterations, temp = 1500e-3
# merge pattern found after 70 iterations, temp = 1500e-3
# merge pattern found after 388 iterations, temp = 1500e-3
# merge pattern found after 616 iterations, temp = 1500e-3
# merge pattern found after 4897 iterations, temp = 1560e-3
# merge pattern found after 212 iterations, temp = 1500e-3
# merge pattern found after 615 iterations, temp = 1500e-3
# merge pattern found after 597 iterations, temp = 1500e-3
# merge pattern found after 3427 iterations, temp = 1545e-3
# merge pattern found after 1634 iterations, temp = 1515e-3
# merge pattern found after 871 iterations, temp = 1500e-3
# merge pattern found after 1528 iterations, temp = 1515e-3
# merge pattern found after 914 iterations, temp = 1500e-3
# merge pattern found after 3031 iterations, temp = 1545e-3
# merge pattern found after 744 iterations, temp = 1500e-3
# merge pattern found after 1596 iterations, temp = 1515e-3
# merge pattern found after 1351 iterations, temp = 1515e-3
# merge pattern found after 428 iterations, temp = 1500e-3
# merge pattern found after 80 iterations, temp = 1500e-3
# merge pattern found after 696 iterations, temp = 1500e-3
# merge pattern found after 1845 iterations, temp = 1515e-3
# merge pattern found after 3897 iterations, temp = 1545e-3
# merge pattern found after 640 iterations, temp = 1500e-3
# merge pattern found after 288 iterations, temp = 1500e-3
# merge pattern found after 2311 iterations, temp = 1530e-3
# merge pattern found after 2695 iterations, temp = 1530e-3
# merge pattern found after 2276 iterations, temp = 1530e-3
# merge pattern found after 3159 iterations, temp = 1545e-3
# merge pattern found after 3888 iterations, temp = 1545e-3
# merge pattern found after 1362 iterations, temp = 1515e-3
# merge pattern found after 663 iterations, temp = 1500e-3
# merge pattern found after 115 iterations, temp = 1500e-3
# merge pattern found after 544 iterations, temp = 1500e-3
# merge pattern found after 427 iterations, temp = 1500e-3
# merge pattern found after 1715 iterations, temp = 1515e-3
# merge pattern found after 800 iterations, temp = 1500e-3
# merge pattern found after 519 iterations, temp = 1500e-3
# merge pattern found after 39 iterations, temp = 1500e-3
# merge pattern found after 821 iterations, temp = 1500e-3
# merge pattern found after 2155 iterations, temp = 1530e-3
# merge pattern found after 1810 iterations, temp = 1515e-3
# merge pattern found after 5356 iterations, temp = 1576e-3
# merge pattern found after 249 iterations, temp = 1500e-3
# merge pattern found after 817 iterations, temp = 1500e-3
# merge pattern found after 2687 iterations, temp = 1530e-3
# merge pattern found after 3728 iterations, temp = 1545e-3
# merge pattern found after 6183 iterations, temp = 1592e-3
# merge pattern found after 592 iterations, temp = 1500e-3
# merge pattern found after 3327 iterations, temp = 1545e-3
# merge pattern found after 5266 iterations, temp = 1576e-3
# merge pattern found after 335 iterations, temp = 1500e-3
# merge pattern found after 255 iterations, temp = 1500e-3
# merge pattern found after 2800 iterations, temp = 1530e-3
# merge pattern found after 2032 iterations, temp = 1530e-3
# merge pattern found after 3303 iterations, temp = 1545e-3
# merge pattern found after 9510 iterations, temp = 1640e-3
# merge pattern found after 613 iterations, temp = 1500e-3
# merge pattern found after 2517 iterations, temp = 1530e-3
# merge pattern found after 5605 iterations, temp = 1576e-3
# merge pattern found after 1111 iterations, temp = 1515e-3
# merge pattern found after 1342 iterations, temp = 1515e-3
# merge pattern found after 2989 iterations, temp = 1530e-3
# merge pattern found after 13403 iterations, temp = 1707e-3
# merge pattern found after 2016 iterations, temp = 1530e-3
# merge pattern found after 216 iterations, temp = 1500e-3
# merge pattern found after 1957 iterations, temp = 1515e-3
# merge pattern found after 3711 iterations, temp = 1545e-3
# merge pattern found after 1555 iterations, temp = 1515e-3
# merge pattern found after 1150 iterations, temp = 1515e-3
# merge pattern found after 752 iterations, temp = 1500e-3
# merge pattern found after 943 iterations, temp = 1500e-3
# merge pattern found after 155 iterations, temp = 1500e-3
# merge pattern found after 787 iterations, temp = 1500e-3
# merge pattern found after 3093 iterations, temp = 1545e-3
# merge pattern found after 2028 iterations, temp = 1530e-3
# merge pattern found after 297 iterations, temp = 1500e-3
# merge pattern found after 739 iterations, temp = 1500e-3
# merge pattern found after 1085 iterations, temp = 1515e-3
# merge pattern found after 4964 iterations, temp = 1560e-3
# merge pattern found after 474 iterations, temp = 1500e-3
# merge pattern found after 329 iterations, temp = 1500e-3
# merge pattern found after 1378 iterations, temp = 1515e-3
# merge pattern found after 1003 iterations, temp = 1515e-3
# merge pattern found after 6378 iterations, temp = 1592e-3
# merge pattern found after 5213 iterations, temp = 1576e-3
# merge pattern found after 615 iterations, temp = 1500e-3
# merge pattern found after 1283 iterations, temp = 1515e-3
# merge pattern found after 438 iterations, temp = 1500e-3
# merge pattern found after 2162 iterations, temp = 1530e-3
# merge pattern found after 1153 iterations, temp = 1515e-3
# merge pattern found after 6370 iterations, temp = 1592e-3
# merge pattern found after 2971 iterations, temp = 1530e-3
# merge pattern found after 1424 iterations, temp = 1515e-3
# merge pattern found after 1317 iterations, temp = 1515e-3
# merge pattern found after 959 iterations, temp = 1500e-3
# merge pattern found after 1856 iterations, temp = 1515e-3
# merge pattern found after 3088 iterations, temp = 1545e-3
# merge pattern found after 2962 iterations, temp = 1530e-3
# merge pattern found after 1176 iterations, temp = 1515e-3
# merge pattern found after 3113 iterations, temp = 1545e-3
# merge pattern found after 90 iterations, temp = 1500e-3
# merge pattern found after 1308 iterations, temp = 1515e-3
# merge pattern found after 1416 iterations, temp = 1515e-3
# merge pattern found after 115 iterations, temp = 1500e-3
# merge pattern found after 1453 iterations, temp = 1515e-3
# merge pattern found after 424 iterations, temp = 1500e-3
# merge pattern found after 265 iterations, temp = 1500e-3
# merge pattern found after 5165 iterations, temp = 1576e-3
# merge pattern found after 227 iterations, temp = 1500e-3
# merge pattern found after 1311 iterations, temp = 1515e-3
# merge pattern found after 331 iterations, temp = 1500e-3
# merge pattern found after 6484 iterations, temp = 1592e-3
# merge pattern found after 148 iterations, temp = 1500e-3
# merge pattern found after 5655 iterations, temp = 1576e-3
# merge pattern found after 64 iterations, temp = 1500e-3
# merge pattern found after 2641 iterations, temp = 1530e-3
# merge pattern found after 1628 iterations, temp = 1515e-3
# merge pattern found after 851 iterations, temp = 1500e-3
# merge pattern found after 2915 iterations, temp = 1530e-3
# merge pattern found after 76 iterations, temp = 1500e-3
# merge pattern found after 1014 iterations, temp = 1515e-3
# merge pattern found after 899 iterations, temp = 1500e-3
# merge pattern found after 2107 iterations, temp = 1530e-3
# merge pattern found after 7622 iterations, temp = 1608e-3
# merge pattern found after 283 iterations, temp = 1500e-3
# merge pattern found after 3384 iterations, temp = 1545e-3
# merge pattern found after 1267 iterations, temp = 1515e-3
# merge pattern found after 1943 iterations, temp = 1515e-3
# merge pattern found after 465 iterations, temp = 1500e-3
# merge pattern found after 1229 iterations, temp = 1515e-3
# merge pattern found after 652 iterations, temp = 1500e-3
# merge pattern found after 213 iterations, temp = 1500e-3
# merge pattern found after 501 iterations, temp = 1500e-3
# merge pattern found after 842 iterations, temp = 1500e-3
# merge pattern found after 1367 iterations, temp = 1515e-3
# merge pattern found after 1344 iterations, temp = 1515e-3
# merge pattern found after 5971 iterations, temp = 1576e-3
# merge pattern found after 1884 iterations, temp = 1515e-3
# merge pattern found after 6032 iterations, temp = 1592e-3
# merge pattern found after 3882 iterations, temp = 1545e-3
# merge pattern found after 7073 iterations, temp = 1608e-3
# merge pattern found after 39 iterations, temp = 1500e-3
# merge pattern found after 819 iterations, temp = 1500e-3
# merge pattern found after 521 iterations, temp = 1500e-3
# merge pattern found after 1251 iterations, temp = 1515e-3
# merge pattern found after 1970 iterations, temp = 1515e-3
# merge pattern found after 1624 iterations, temp = 1515e-3
# merge pattern found after 470 iterations, temp = 1500e-3
# merge pattern found after 4952 iterations, temp = 1560e-3
# merge pattern found after 2045 iterations, temp = 1530e-3
# merge pattern found after 5082 iterations, temp = 1576e-3
# merge pattern found after 314 iterations, temp = 1500e-3
# merge pattern found after 800 iterations, temp = 1500e-3
# merge pattern found after 596 iterations, temp = 1500e-3
# merge pattern found after 217 iterations, temp = 1500e-3
# merge pattern found after 4092 iterations, temp = 1560e-3
# merge pattern found after 5644 iterations, temp = 1576e-3
# merge pattern found after 561 iterations, temp = 1500e-3
# merge pattern found after 1861 iterations, temp = 1515e-3
# merge pattern found after 404 iterations, temp = 1500e-3
# merge pattern found after 2015 iterations, temp = 1530e-3
# merge pattern found after 2215 iterations, temp = 1530e-3
# merge pattern found after 173 iterations, temp = 1500e-3
# merge pattern found after 942 iterations, temp = 1500e-3
# merge pattern found after 27 iterations, temp = 1500e-3
# merge pattern found after 134 iterations, temp = 1500e-3
# merge pattern found after 120 iterations, temp = 1500e-3
# merge pattern found after 1579 iterations, temp = 1515e-3
# merge pattern found after 539 iterations, temp = 1500e-3
# merge pattern found after 888 iterations, temp = 1500e-3
# merge pattern found after 615 iterations, temp = 1500e-3
# merge pattern found after 492 iterations, temp = 1500e-3
# merge pattern found after 2192 iterations, temp = 1530e-3
# merge pattern found after 372 iterations, temp = 1500e-3
# merge pattern found after 178 iterations, temp = 1500e-3
# merge pattern found after 1196 iterations, temp = 1515e-3
# merge pattern found after 752 iterations, temp = 1500e-3
# merge pattern found after 4337 iterations, temp = 1560e-3
# merge pattern found after 2662 iterations, temp = 1530e-3
# merge pattern found after 3968 iterations, temp = 1545e-3
# merge pattern found after 978 iterations, temp = 1500e-3
# merge pattern found after 264 iterations, temp = 1500e-3
# merge pattern found after 753 iterations, temp = 1500e-3
# merge pattern found after 1623 iterations, temp = 1515e-3
# merge pattern found after 4217 iterations, temp = 1560e-3
# merge pattern found after 149 iterations, temp = 1500e-3
# merge pattern found after 1846 iterations, temp = 1515e-3
# merge pattern found after 266 iterations, temp = 1500e-3
# merge pattern found after 2290 iterations, temp = 1530e-3
# merge pattern found after 1544 iterations, temp = 1515e-3
# merge pattern found after 1693 iterations, temp = 1515e-3
# merge pattern found after 396 iterations, temp = 1500e-3
# merge pattern found after 2979 iterations, temp = 1530e-3
# merge pattern found after 7336 iterations, temp = 1608e-3
# merge pattern found after 1323 iterations, temp = 1515e-3
# merge pattern found after 1028 iterations, temp = 1515e-3
# merge pattern found after 310 iterations, temp = 1500e-3
# merge pattern found after 35 iterations, temp = 1500e-3
# merge pattern found after 776 iterations, temp = 1500e-3
# merge pattern found after 230 iterations, temp = 1500e-3
# merge pattern found after 986 iterations, temp = 1500e-3
# merge pattern found after 2230 iterations, temp = 1530e-3
# merge pattern found after 2051 iterations, temp = 1530e-3
# merge pattern found after 2097 iterations, temp = 1530e-3
# merge pattern found after 1543 iterations, temp = 1515e-3
# merge pattern found after 517 iterations, temp = 1500e-3
# merge pattern found after 95 iterations, temp = 1500e-3
# merge pattern found after 847 iterations, temp = 1500e-3
# merge pattern found after 1718 iterations, temp = 1515e-3
# merge pattern found after 164 iterations, temp = 1500e-3
# merge pattern found after 570 iterations, temp = 1500e-3
# merge pattern found after 1287 iterations, temp = 1515e-3
# merge pattern found after 1506 iterations, temp = 1515e-3
# merge pattern found after 385 iterations, temp = 1500e-3
# merge pattern found after 795 iterations, temp = 1500e-3
# merge pattern found after 1617 iterations, temp = 1515e-3
# merge pattern found after 250 iterations, temp = 1500e-3
# merge pattern found after 1245 iterations, temp = 1515e-3
# merge pattern found after 1882 iterations, temp = 1515e-3
# merge pattern found after 711 iterations, temp = 1500e-3
# merge pattern found after 519 iterations, temp = 1500e-3
# merge pattern found after 810 iterations, temp = 1500e-3
# merge pattern found after 4824 iterations, temp = 1560e-3
# merge pattern found after 8289 iterations, temp = 1624e-3
# merge pattern found after 5408 iterations, temp = 1576e-3
# merge pattern found after 828 iterations, temp = 1500e-3
# merge pattern found after 8585 iterations, temp = 1624e-3
# merge pattern found after 74 iterations, temp = 1500e-3
# merge pattern found after 494 iterations, temp = 1500e-3
# merge pattern found after 767 iterations, temp = 1500e-3
# merge pattern found after 62 iterations, temp = 1500e-3
# merge pattern found after 231 iterations, temp = 1500e-3
# merge pattern found after 2842 iterations, temp = 1530e-3
# merge pattern found after 2252 iterations, temp = 1530e-3
# merge pattern found after 6008 iterations, temp = 1592e-3
# merge pattern found after 1661 iterations, temp = 1515e-3
# merge pattern found after 540 iterations, temp = 1500e-3
# merge pattern found after 746 iterations, temp = 1500e-3
# merge pattern found after 5015 iterations, temp = 1576e-3
# merge pattern found after 190 iterations, temp = 1500e-3
# merge pattern found after 1945 iterations, temp = 1515e-3
# merge pattern found after 1609 iterations, temp = 1515e-3
# merge pattern found after 1386 iterations, temp = 1515e-3
# merge pattern found after 465 iterations, temp = 1500e-3
# merge pattern found after 192 iterations, temp = 1500e-3
# merge pattern found after 104 iterations, temp = 1500e-3
# merge pattern found after 331 iterations, temp = 1500e-3
# merge pattern found after 1002 iterations, temp = 1515e-3
# merge pattern found after 855 iterations, temp = 1500e-3
# merge pattern found after 888 iterations, temp = 1500e-3
# merge pattern found after 4621 iterations, temp = 1560e-3
# merge pattern found after 358 iterations, temp = 1500e-3
# merge pattern found after 883 iterations, temp = 1500e-3
# merge pattern found after 3702 iterations, temp = 1545e-3
# merge pattern found after 551 iterations, temp = 1500e-3
# merge pattern found after 4614 iterations, temp = 1560e-3
# merge pattern found after 1114 iterations, temp = 1515e-3
# merge pattern found after 3261 iterations, temp = 1545e-3
# merge pattern found after 586 iterations, temp = 1500e-3
# merge pattern found after 7561 iterations, temp = 1608e-3
# merge pattern found after 982 iterations, temp = 1500e-3
# merge pattern found after 2066 iterations, temp = 1530e-3
# merge pattern found after 1055 iterations, temp = 1515e-3
# merge pattern found after 2250 iterations, temp = 1530e-3
# merge pattern found after 1669 iterations, temp = 1515e-3
# merge pattern found after 7351 iterations, temp = 1608e-3
# merge pattern found after 269 iterations, temp = 1500e-3
# merge pattern found after 111 iterations, temp = 1500e-3
# merge pattern found after 262 iterations, temp = 1500e-3
# merge pattern found after 96 iterations, temp = 1500e-3
# merge pattern found after 1151 iterations, temp = 1515e-3
# merge pattern found after 4630 iterations, temp = 1560e-3
# merge pattern found after 77 iterations, temp = 1500e-3
# merge pattern found after 3253 iterations, temp = 1545e-3
# merge pattern found after 585 iterations, temp = 1500e-3
# merge pattern found after 3538 iterations, temp = 1545e-3
# merge pattern found after 185 iterations, temp = 1500e-3
# merge pattern found after 656 iterations, temp = 1500e-3
# merge pattern found after 494 iterations, temp = 1500e-3
# merge pattern found after 549 iterations, temp = 1500e-3
# merge pattern found after 1729 iterations, temp = 1515e-3
# merge pattern found after 151 iterations, temp = 1500e-3
# merge pattern found after 628 iterations, temp = 1500e-3
# merge pattern found after 42 iterations, temp = 1500e-3
# merge pattern found after 4328 iterations, temp = 1560e-3
# merge pattern found after 2303 iterations, temp = 1530e-3
# merge pattern found after 3287 iterations, temp = 1545e-3
# merge pattern found after 3838 iterations, temp = 1545e-3
# merge pattern found after 1518 iterations, temp = 1515e-3
# merge pattern found after 2312 iterations, temp = 1530e-3
# merge pattern found after 110 iterations, temp = 1500e-3
# merge pattern found after 185 iterations, temp = 1500e-3
# merge pattern found after 2937 iterations, temp = 1530e-3
# merge pattern found after 2218 iterations, temp = 1530e-3
# merge pattern found after 419 iterations, temp = 1500e-3
# merge pattern found after 1489 iterations, temp = 1515e-3
# merge pattern found after 108 iterations, temp = 1500e-3
# merge pattern found after 2017 iterations, temp = 1530e-3
# merge pattern found after 2546 iterations, temp = 1530e-3
# merge pattern found after 188 iterations, temp = 1500e-3
# merge pattern found after 228 iterations, temp = 1500e-3
# merge pattern found after 145 iterations, temp = 1500e-3
# merge pattern found after 1643 iterations, temp = 1515e-3
# merge pattern found after 7622 iterations, temp = 1608e-3
# merge pattern found after 4484 iterations, temp = 1560e-3
# merge pattern found after 2210 iterations, temp = 1530e-3
# merge pattern found after 2303 iterations, temp = 1530e-3
# merge pattern found after 8778 iterations, temp = 1624e-3
# merge pattern found after 4889 iterations, temp = 1560e-3
# merge pattern found after 1505 iterations, temp = 1515e-3
# merge pattern found after 2316 iterations, temp = 1530e-3
# merge pattern found after 617 iterations, temp = 1500e-3
# merge pattern found after 2461 iterations, temp = 1530e-3
# merge pattern found after 145 iterations, temp = 1500e-3
# merge pattern found after 3722 iterations, temp = 1545e-3
# merge pattern found after 173 iterations, temp = 1500e-3
# merge pattern found after 2576 iterations, temp = 1530e-3
# merge pattern found after 4460 iterations, temp = 1560e-3
# merge pattern found after 2463 iterations, temp = 1530e-3
# merge pattern found after 1349 iterations, temp = 1515e-3
# merge pattern found after 5208 iterations, temp = 1576e-3
# merge pattern found after 1442 iterations, temp = 1515e-3
# merge pattern found after 1966 iterations, temp = 1515e-3
# merge pattern found after 270 iterations, temp = 1500e-3
# merge pattern found after 2332 iterations, temp = 1530e-3
# merge pattern found after 2735 iterations, temp = 1530e-3
# merge pattern found after 5772 iterations, temp = 1576e-3
# merge pattern found after 436 iterations, temp = 1500e-3
# merge pattern found after 654 iterations, temp = 1500e-3
# merge pattern found after 1895 iterations, temp = 1515e-3
# merge pattern found after 849 iterations, temp = 1500e-3
# merge pattern found after 4207 iterations, temp = 1560e-3
# merge pattern found after 1506 iterations, temp = 1515e-3
# merge pattern found after 1961 iterations, temp = 1515e-3
# merge pattern found after 426 iterations, temp = 1500e-3
# merge pattern found after 2926 iterations, temp = 1530e-3
# merge pattern found after 1557 iterations, temp = 1515e-3
# merge pattern found after 4512 iterations, temp = 1560e-3
# merge pattern found after 81 iterations, temp = 1500e-3
# merge pattern found after 458 iterations, temp = 1500e-3
# merge pattern found after 2230 iterations, temp = 1530e-3
# merge pattern found after 5634 iterations, temp = 1576e-3
# merge pattern found after 4824 iterations, temp = 1560e-3
# merge pattern found after 3075 iterations, temp = 1545e-3
# merge pattern found after 3563 iterations, temp = 1545e-3
# merge pattern found after 1551 iterations, temp = 1515e-3
# merge pattern found after 5867 iterations, temp = 1576e-3
# merge pattern found after 1084 iterations, temp = 1515e-3
# merge pattern found after 962 iterations, temp = 1500e-3
# merge pattern found after 1193 iterations, temp = 1515e-3
# merge pattern found after 983 iterations, temp = 1500e-3
# merge pattern found after 714 iterations, temp = 1500e-3
# merge pattern found after 1342 iterations, temp = 1515e-3
# merge pattern found after 748 iterations, temp = 1500e-3
# merge pattern found after 718 iterations, temp = 1500e-3
# merge pattern found after 363 iterations, temp = 1500e-3
# merge pattern found after 119 iterations, temp = 1500e-3
# merge pattern found after 1948 iterations, temp = 1515e-3
# merge pattern found after 3668 iterations, temp = 1545e-3
# merge pattern found after 1489 iterations, temp = 1515e-3
# merge pattern found after 560 iterations, temp = 1500e-3
# merge pattern found after 1929 iterations, temp = 1515e-3
# merge pattern found after 389 iterations, temp = 1500e-3
# merge pattern found after 1338 iterations, temp = 1515e-3
# merge pattern found after 3952 iterations, temp = 1545e-3
# merge pattern found after 4884 iterations, temp = 1560e-3
# merge pattern found after 661 iterations, temp = 1500e-3
# merge pattern found after 1074 iterations, temp = 1515e-3
# merge pattern found after 7917 iterations, temp = 1608e-3
# merge pattern found after 1097 iterations, temp = 1515e-3
# merge pattern found after 627 iterations, temp = 1500e-3
# merge pattern found after 11093 iterations, temp = 1673e-3
# merge pattern found after 398 iterations, temp = 1500e-3
# merge pattern found after 1963 iterations, temp = 1515e-3
# merge pattern found after 2328 iterations, temp = 1530e-3
# merge pattern found after 2651 iterations, temp = 1530e-3
# merge pattern found after 1264 iterations, temp = 1515e-3
# merge pattern found after 82 iterations, temp = 1500e-3
# merge pattern found after 5762 iterations, temp = 1576e-3
# merge pattern found after 12 iterations, temp = 1500e-3
# merge pattern found after 233 iterations, temp = 1500e-3
# merge pattern found after 5353 iterations, temp = 1576e-3
# merge pattern found after 2271 iterations, temp = 1530e-3
# merge pattern found after 310 iterations, temp = 1500e-3
# merge pattern found after 6340 iterations, temp = 1592e-3
# merge pattern found after 282 iterations, temp = 1500e-3
# merge pattern found after 3040 iterations, temp = 1545e-3
# merge pattern found after 1574 iterations, temp = 1515e-3
# merge pattern found after 1939 iterations, temp = 1515e-3
# merge pattern found after 4265 iterations, temp = 1560e-3
# merge pattern found after 4944 iterations, temp = 1560e-3
# merge pattern found after 5209 iterations, temp = 1576e-3
# merge pattern found after 106 iterations, temp = 1500e-3
# merge pattern found after 569 iterations, temp = 1500e-3
# merge pattern found after 338 iterations, temp = 1500e-3
# merge pattern found after 2061 iterations, temp = 1530e-3
# merge pattern found after 2854 iterations, temp = 1530e-3
# merge pattern found after 3179 iterations, temp = 1545e-3
# merge pattern found after 8539 iterations, temp = 1624e-3
# merge pattern found after 4988 iterations, temp = 1560e-3
# merge pattern found after 208 iterations, temp = 1500e-3
# merge pattern found after 1729 iterations, temp = 1515e-3
# merge pattern found after 3004 iterations, temp = 1545e-3
# merge pattern found after 1319 iterations, temp = 1515e-3
# merge pattern found after 541 iterations, temp = 1500e-3
# merge pattern found after 1331 iterations, temp = 1515e-3
# merge pattern found after 39 iterations, temp = 1500e-3
# merge pattern found after 279 iterations, temp = 1500e-3
# merge pattern found after 1502 iterations, temp = 1515e-3
# merge pattern found after 134 iterations, temp = 1500e-3
# merge pattern found after 4165 iterations, temp = 1560e-3
# merge pattern found after 3012 iterations, temp = 1545e-3
# merge pattern found after 902 iterations, temp = 1500e-3
# merge pattern found after 1107 iterations, temp = 1515e-3
# merge pattern found after 1625 iterations, temp = 1515e-3
# merge pattern found after 608 iterations, temp = 1500e-3
# merge pattern found after 715 iterations, temp = 1500e-3
# merge pattern found after 7580 iterations, temp = 1608e-3
# merge pattern found after 2555 iterations, temp = 1530e-3
# merge pattern found after 316 iterations, temp = 1500e-3
# merge pattern found after 1374 iterations, temp = 1515e-3
# merge pattern found after 4158 iterations, temp = 1560e-3
# merge pattern found after 1387 iterations, temp = 1515e-3
# merge pattern found after 1538 iterations, temp = 1515e-3
# merge pattern found after 501 iterations, temp = 1500e-3
# merge pattern found after 1995 iterations, temp = 1515e-3
# merge pattern found after 1156 iterations, temp = 1515e-3
# merge pattern found after 1596 iterations, temp = 1515e-3
# merge pattern found after 5 iterations, temp = 1500e-3
# merge pattern found after 6170 iterations, temp = 1592e-3
# merge pattern found after 689 iterations, temp = 1500e-3
# merge pattern found after 2856 iterations, temp = 1530e-3
# merge pattern found after 4054 iterations, temp = 1560e-3
# merge pattern found after 2309 iterations, temp = 1530e-3
# merge pattern found after 6696 iterations, temp = 1592e-3
# merge pattern found after 812 iterations, temp = 1500e-3
# merge pattern found after 1595 iterations, temp = 1515e-3
# merge pattern found after 1458 iterations, temp = 1515e-3
# merge pattern found after 1128 iterations, temp = 1515e-3
# merge pattern found after 5232 iterations, temp = 1576e-3
# merge pattern found after 1280 iterations, temp = 1515e-3
# merge pattern found after 2493 iterations, temp = 1530e-3
# merge pattern found after 1521 iterations, temp = 1515e-3
# merge pattern found after 1111 iterations, temp = 1515e-3
# merge pattern found after 1562 iterations, temp = 1515e-3
# merge pattern found after 284 iterations, temp = 1500e-3
# merge pattern found after 3379 iterations, temp = 1545e-3
# merge pattern found after 1706 iterations, temp = 1515e-3
# merge pattern found after 1783 iterations, temp = 1515e-3
# merge pattern found after 6081 iterations, temp = 1592e-3
# merge pattern found after 5724 iterations, temp = 1576e-3
# merge pattern found after 67 iterations, temp = 1500e-3
# merge pattern found after 144 iterations, temp = 1500e-3
# merge pattern found after 1217 iterations, temp = 1515e-3
# merge pattern found after 471 iterations, temp = 1500e-3
# merge pattern found after 195 iterations, temp = 1500e-3
# merge pattern found after 659 iterations, temp = 1500e-3
# merge pattern found after 1815 iterations, temp = 1515e-3
# merge pattern found after 1592 iterations, temp = 1515e-3
# merge pattern found after 3982 iterations, temp = 1545e-3
# merge pattern found after 26 iterations, temp = 1500e-3
# merge pattern found after 4573 iterations, temp = 1560e-3
# merge pattern found after 1238 iterations, temp = 1515e-3
# merge pattern found after 248 iterations, temp = 1500e-3
# merge pattern found after 5364 iterations, temp = 1576e-3
# merge pattern found after 264 iterations, temp = 1500e-3
# merge pattern found after 1875 iterations, temp = 1515e-3
# merge pattern found after 191 iterations, temp = 1500e-3
# merge pattern found after 2325 iterations, temp = 1530e-3
# merge pattern found after 3530 iterations, temp = 1545e-3
# merge pattern found after 2929 iterations, temp = 1530e-3
# merge pattern found after 114 iterations, temp = 1500e-3
# merge pattern found after 4386 iterations, temp = 1560e-3
# merge pattern found after 4686 iterations, temp = 1560e-3
# merge pattern found after 3610 iterations, temp = 1545e-3
# merge pattern found after 2574 iterations, temp = 1530e-3
# merge pattern found after 634 iterations, temp = 1500e-3
# merge pattern found after 1207 iterations, temp = 1515e-3
# merge pattern found after 2442 iterations, temp = 1530e-3
# merge pattern found after 520 iterations, temp = 1500e-3
# merge pattern found after 1576 iterations, temp = 1515e-3
# merge pattern found after 302 iterations, temp = 1500e-3
# merge pattern found after 168 iterations, temp = 1500e-3
# merge pattern found after 641 iterations, temp = 1500e-3
# merge pattern found after 1618 iterations, temp = 1515e-3
# merge pattern found after 439 iterations, temp = 1500e-3
# merge pattern found after 327 iterations, temp = 1500e-3
# merge pattern found after 1981 iterations, temp = 1515e-3
# merge pattern found after 1395 iterations, temp = 1515e-3
# merge pattern found after 3306 iterations, temp = 1545e-3
# merge pattern found after 3022 iterations, temp = 1545e-3
# merge pattern found after 644 iterations, temp = 1500e-3
# merge pattern found after 397 iterations, temp = 1500e-3
# merge pattern found after 7987 iterations, temp = 1608e-3
# merge pattern found after 3529 iterations, temp = 1545e-3
# merge pattern found after 484 iterations, temp = 1500e-3
# merge pattern found after 3366 iterations, temp = 1545e-3
# merge pattern found after 6213 iterations, temp = 1592e-3
# merge pattern found after 420 iterations, temp = 1500e-3
# merge pattern found after 1738 iterations, temp = 1515e-3
# merge pattern found after 754 iterations, temp = 1500e-3
# merge pattern found after 1311 iterations, temp = 1515e-3
# merge pattern found after 259 iterations, temp = 1500e-3
# merge pattern found after 1656 iterations, temp = 1515e-3
# merge pattern found after 2262 iterations, temp = 1530e-3
# merge pattern found after 322 iterations, temp = 1500e-3
# merge pattern found after 929 iterations, temp = 1500e-3
# merge pattern found after 3858 iterations, temp = 1545e-3
# merge pattern found after 2233 iterations, temp = 1530e-3
# merge pattern found after 787 iterations, temp = 1500e-3
# merge pattern found after 4394 iterations, temp = 1560e-3
# merge pattern found after 3478 iterations, temp = 1545e-3
# merge pattern found after 3132 iterations, temp = 1545e-3
# merge pattern found after 636 iterations, temp = 1500e-3
# merge pattern found after 2402 iterations, temp = 1530e-3
# merge pattern found after 2538 iterations, temp = 1530e-3
# merge pattern found after 1362 iterations, temp = 1515e-3
# merge pattern found after 1085 iterations, temp = 1515e-3
# merge pattern found after 3374 iterations, temp = 1545e-3
# merge pattern found after 107 iterations, temp = 1500e-3
# merge pattern found after 1132 iterations, temp = 1515e-3
# merge pattern found after 2157 iterations, temp = 1530e-3
# merge pattern found after 6399 iterations, temp = 1592e-3
# merge pattern found after 632 iterations, temp = 1500e-3
# merge pattern found after 303 iterations, temp = 1500e-3
# merge pattern found after 1036 iterations, temp = 1515e-3
# merge pattern found after 4471 iterations, temp = 1560e-3
# merge pattern found after 1926 iterations, temp = 1515e-3
# merge pattern found after 1093 iterations, temp = 1515e-3
# merge pattern found after 510 iterations, temp = 1500e-3
# merge pattern found after 972 iterations, temp = 1500e-3
# merge pattern found after 2781 iterations, temp = 1530e-3
# merge pattern found after 1614 iterations, temp = 1515e-3
# merge pattern found after 3008 iterations, temp = 1545e-3
# merge pattern found after 317 iterations, temp = 1500e-3
# merge pattern found after 1703 iterations, temp = 1515e-3
# merge pattern found after 145 iterations, temp = 1500e-3
# merge pattern found after 1701 iterations, temp = 1515e-3
# merge pattern found after 5614 iterations, temp = 1576e-3
# merge pattern found after 2338 iterations, temp = 1530e-3
# merge pattern found after 2849 iterations, temp = 1530e-3
# merge pattern found after 2137 iterations, temp = 1530e-3
# merge pattern found after 1952 iterations, temp = 1515e-3
# merge pattern found after 844 iterations, temp = 1500e-3
# merge pattern found after 191 iterations, temp = 1500e-3
# merge pattern found after 2407 iterations, temp = 1530e-3
# merge pattern found after 3008 iterations, temp = 1545e-3
# merge pattern found after 1285 iterations, temp = 1515e-3
# merge pattern found after 2813 iterations, temp = 1530e-3
# merge pattern found after 4587 iterations, temp = 1560e-3
# merge pattern found after 138 iterations, temp = 1500e-3
# merge pattern found after 1995 iterations, temp = 1515e-3
# merge pattern found after 575 iterations, temp = 1500e-3
# merge pattern found after 67 iterations, temp = 1500e-3
# merge pattern found after 332 iterations, temp = 1500e-3
# merge pattern found after 218 iterations, temp = 1500e-3
# merge pattern found after 3148 iterations, temp = 1545e-3
# merge pattern found after 1669 iterations, temp = 1515e-3
# merge pattern found after 4577 iterations, temp = 1560e-3
# merge pattern found after 1971 iterations, temp = 1515e-3
# merge pattern found after 679 iterations, temp = 1500e-3
# merge pattern found after 1268 iterations, temp = 1515e-3
# merge pattern found after 2277 iterations, temp = 1530e-3
# merge pattern found after 382 iterations, temp = 1500e-3
# merge pattern found after 1380 iterations, temp = 1515e-3
# merge pattern found after 960 iterations, temp = 1500e-3
# merge pattern found after 3366 iterations, temp = 1545e-3
# merge pattern found after 5649 iterations, temp = 1576e-3
# merge pattern found after 3383 iterations, temp = 1545e-3
# merge pattern found after 1874 iterations, temp = 1515e-3
# merge pattern found after 94 iterations, temp = 1500e-3
# merge pattern found after 1634 iterations, temp = 1515e-3
# merge pattern found after 2587 iterations, temp = 1530e-3
# merge pattern found after 3836 iterations, temp = 1545e-3
# merge pattern found after 95 iterations, temp = 1500e-3
# merge pattern found after 1508 iterations, temp = 1515e-3
# merge pattern found after 1388 iterations, temp = 1515e-3
# merge pattern found after 984 iterations, temp = 1500e-3
# merge pattern found after 825 iterations, temp = 1500e-3
# merge pattern found after 5215 iterations, temp = 1576e-3
# merge pattern found after 3177 iterations, temp = 1545e-3
# merge pattern found after 2089 iterations, temp = 1530e-3
# merge pattern found after 2490 iterations, temp = 1530e-3
# merge pattern found after 1540 iterations, temp = 1515e-3
# merge pattern found after 826 iterations, temp = 1500e-3
# merge pattern found after 1286 iterations, temp = 1515e-3
# merge pattern found after 845 iterations, temp = 1500e-3
# merge pattern found after 348 iterations, temp = 1500e-3
# merge pattern found after 749 iterations, temp = 1500e-3
# merge pattern found after 1062 iterations, temp = 1515e-3
# merge pattern found after 3016 iterations, temp = 1545e-3
# merge pattern found after 2060 iterations, temp = 1530e-3
# merge pattern found after 847 iterations, temp = 1500e-3
# merge pattern found after 1438 iterations, temp = 1515e-3
# merge pattern found after 496 iterations, temp = 1500e-3
# merge pattern found after 221 iterations, temp = 1500e-3
# merge pattern found after 1909 iterations, temp = 1515e-3
# merge pattern found after 202 iterations, temp = 1500e-3
# merge pattern found after 1731 iterations, temp = 1515e-3
# merge pattern found after 4687 iterations, temp = 1560e-3
# merge pattern found after 2147 iterations, temp = 1530e-3
# merge pattern found after 767 iterations, temp = 1500e-3
# merge pattern found after 1642 iterations, temp = 1515e-3
# merge pattern found after 556 iterations, temp = 1500e-3
# merge pattern found after 88 iterations, temp = 1500e-3
# merge pattern found after 2830 iterations, temp = 1530e-3
# merge pattern found after 6367 iterations, temp = 1592e-3
# merge pattern found after 3299 iterations, temp = 1545e-3
# merge pattern found after 257 iterations, temp = 1500e-3
# merge pattern found after 3612 iterations, temp = 1545e-3
# merge pattern found after 173 iterations, temp = 1500e-3
# merge pattern found after 752 iterations, temp = 1500e-3
# merge pattern found after 1147 iterations, temp = 1515e-3
# merge pattern found after 2016 iterations, temp = 1530e-3
# merge pattern found after 169 iterations, temp = 1500e-3
# merge pattern found after 1067 iterations, temp = 1515e-3
# merge pattern found after 3661 iterations, temp = 1545e-3
# merge pattern found after 599 iterations, temp = 1500e-3
# merge pattern found after 2679 iterations, temp = 1530e-3
# merge pattern found after 759 iterations, temp = 1500e-3
# merge pattern found after 1076 iterations, temp = 1515e-3
# merge pattern found after 6721 iterations, temp = 1592e-3
# merge pattern found after 9435 iterations, temp = 1640e-3
# merge pattern found after 1947 iterations, temp = 1515e-3
# merge pattern found after 1131 iterations, temp = 1515e-3
# merge pattern found after 4459 iterations, temp = 1560e-3
# merge pattern found after 251 iterations, temp = 1500e-3
# merge pattern found after 134 iterations, temp = 1500e-3
# merge pattern found after 3554 iterations, temp = 1545e-3
# merge pattern found after 5627 iterations, temp = 1576e-3
# merge pattern found after 1323 iterations, temp = 1515e-3
# merge pattern found after 893 iterations, temp = 1500e-3
# merge pattern found after 1610 iterations, temp = 1515e-3
# merge pattern found after 628 iterations, temp = 1500e-3
# merge pattern found after 1191 iterations, temp = 1515e-3
# merge pattern found after 1904 iterations, temp = 1515e-3
# merge pattern found after 1453 iterations, temp = 1515e-3
# merge pattern found after 849 iterations, temp = 1500e-3
# merge pattern found after 283 iterations, temp = 1500e-3
# merge pattern found after 2409 iterations, temp = 1530e-3
# merge pattern found after 2318 iterations, temp = 1530e-3
# merge pattern found after 2015 iterations, temp = 1530e-3
# merge pattern found after 4378 iterations, temp = 1560e-3
# merge pattern found after 63 iterations, temp = 1500e-3
# merge pattern found after 3530 iterations, temp = 1545e-3
# merge pattern found after 18549 iterations, temp = 1794e-3
# merge pattern found after 6241 iterations, temp = 1592e-3
# merge pattern found after 1588 iterations, temp = 1515e-3
# 9.66 ms ± 1.06 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
forest = np.stack((trees,roots))

# %%
fast_generator.plot_forest(forest, solution=True, cmap=desert_cmap())
